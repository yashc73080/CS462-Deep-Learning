# %%
import sys
sys.path.insert(0, r"c:\Users\hsayc\dev\CS462-Deep-Learning")

from Minesweeper.GameEnvironment import GameEnvironment
from Minesweeper.LogicBot import LogicBot
from Minesweeper.dataset.Task1Dataset import Task1Dataset
from Minesweeper.models.MinePredictionNet import MinePredictionNet
from Minesweeper.train_test import train_model, test_model

# %%
import torch
from torch.utils.data import DataLoader
import numpy as np
import random

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True
print(f"Using device: {device}")

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
# Out:
# Using device: cuda

# %% [markdown]
# # Task 1

# %% [markdown]
# Load Data

# %%
difficulty = 'medium'

train_dataset = Task1Dataset(num_samples=20000, difficulty=difficulty)
val_dataset = Task1Dataset(num_samples=3000, difficulty=difficulty)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True, persistent_workers=True)

# %% [markdown]
# Build and train model

# %%
medium_model = MinePredictionNet(input_size=(12, 22, 22), device=device)
medium_model, med_train_losses, med_val_losses = train_model(medium_model, train_loader, val_loader, num_epochs=10, lr=0.001, decay=0.0001, plot=True, device=device,
                                                             checkpoint_path='checkpoints/medium_model.pth')
med_acc = test_model(medium_model, val_loader, device=device)

print(f'Final Validation Accuracy: {med_acc:.4f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 medium_model = MinePredictionNet(input_size=(12, 22, 22), device=device)
# ----> 2 medium_model, med_train_losses, med_val_losses = train_model(medium_model, train_loader, val_loader, num_epochs=10, lr=0.001, decay=0.0001, plot=True, device=device,
#       3                                                              checkpoint_path='checkpoints/medium_model.pth')
#       4 med_acc = test_model(medium_model, val_loader, device=device)
#       6 print(f'Final Validation Accuracy: {med_acc:.4f}')
#
# File c:\Users\hsayc\dev\CS462-Deep-Learning\Minesweeper\train_test.py:117, in train_model(model, train_loader, test_loader, num_epochs, lr, decay, plot, device, checkpoint_path, resume, save_every, strict_load)
#     115 model.train()
#     116 running_loss = 0.0
# ...
